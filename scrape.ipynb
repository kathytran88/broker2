# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
import time 

driver = webdriver.Chrome()
driver.get('https://www.bizquest.com/nevada-business-brokers/page-3/')
time.sleep(10)

page_source = driver.page_source 
soup = BeautifulSoup(page_source, 'html.parser')

## Dictionary ##
brokers = []

locations = soup.find_all('div', {'class': 'row broker'})

for location in locations:
    broker = {
        'company': 'N/A',
        'name': 'N/A',
        'state': 'N/A',
        'link': 'N/A'
    }

    # Link
    try:
        #link_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
        link_loc2 = location.find('a', {'class': "bnw-result"})
        link = link_loc2['href']
        broker['link'] = link
    except:
         print('No url found')

    # Name 
    try:
         #name_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
         #name_loc2 = name_loc1.find('div', {'class': 'brokerInfo'})
         #name_loc3 = name_loc2.find('a', {'class': 'bnw-result'})
         name_loc4 = location.find('p', {'class': 'brokerName'})
         name = name_loc4.contents[0].strip()
         broker['name'] = name
    except:
         print('No name found')

    # State & Company
    try:
         #state_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCompany'})
         state_loc2 = location.find('p', {'class': 'brokerage'})
         company = state_loc2.contents[0].strip()

         state_loc3 = state_loc2.find('span', {'class': 'brokerLocation'})
         state = state_loc3.get_text(strip=True)

         broker['company'] = company 
         broker['state'] = state
    except:
         print('No state and company found')

    # Add 
    brokers.append(broker)

driver.quit()

# %%
print(brokers)
# Out:
# [{'company': 'Transworld Business Advisors South Las Vegas', 'name': 'Michael Johnson', 'state': 'Henderson, Nevada', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors-south-las-vegas/michael-johnson/BW46172/'}, {'company': 'Sunbelt Business Brokers of Las Vegas', 'name': 'Alan Horwitz', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/sunbelt-business-brokers-of-las-vegas/alan-horwitz/BW25679/'}, {'company': 'Transworld Business Advisors', 'name': 'Bruce Hooker PC', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors/bruce-hooker-pc/BW40470/'}, {'company': 'LVCBS', 'name': 'Jim  Handler', 'state': 'Henderson, Nevada', 'link': 'https://www.bizquest.com/business-broker/lvcbs/jim-handler/BW17449/'}, {'company': 'BHHS NEVADA PROPERTIES', 'name': 'Elizabeth Hahn', 'state': 'Nevada', 'link': 'https://www.bizquest.com/business-broker/bhhs-nevada-properties/elizabeth-hahn/BW48649/'}, {'company': 'The Liberty Group of Nevada', 'name': 'Stewart Guthrie', 'state': 'Reno, Nevada', 'link': 'https://www.bizquest.com/business-broker/the-liberty-group-of-nevada/stewart-guthrie/BW3105/'}, {'company': 'First Choice Business Brokers', 'name': 'Larry Goldstein', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/first-choice-business-brokers/larry-goldstein/BW38866/'}, {'company': 'BHHS NEVADA PROPERTIES', 'name': 'Mary Giuliano', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/bhhs-nevada-properties/mary-giuliano/BW46349/'}, {'company': 'First Choice Business Brokers', 'name': 'Mike  Faust', 'state': 'Nevada', 'link': 'https://www.bizquest.com/business-broker/first-choice-business-brokers/mike-faust/BW18238/'}, {'company': 'M&A Business Advisors', 'name': 'Todd Elam', 'state': 'Reno, Nevada', 'link': 'https://www.bizquest.com/business-broker/manda-business-advisors/todd-elam/BW23770/'}, {'company': 'Northcap Commercial', 'name': 'Les  Eisinga', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/northcap-commercial/les-eisinga/BW17298/'}, {'company': 'Las Vegas Business Broker, Michael Cash, Benchmark Business Advisors', 'name': 'Michael Cash', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/las-vegas-business-broker-michael-cash-benchmark-business-advisors/michael-cash/BW15053/'}, {'company': 'Transworld Business Advisors South Las Vegas', 'name': 'David Bryan', 'state': 'Henderson, Nevada', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors-south-las-vegas/david-bryan/BW48283/'}, {'company': 'Belltree LLC', 'name': 'John Brassner', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/belltree-llc/john-brassner/BW24588/'}, {'company': 'Signature Real Estate Group', 'name': 'Jeffrey Bradshaw', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/signature-real-estate-group/jeffrey-bradshaw/BW40134/'}, {'company': 'Avison Young', 'name': 'Tony  Amato', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/avison-young/tony-amato/BW17836/'}, {'company': 'First Choice Business Brokers', 'name': 'Eric and Giselle Speer', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/first-choice-business-brokers/eric-and-giselle-speer/BW47293/'}, {'company': 'Sunbelt Business Brokers of Las Vegas', 'name': 'Adam Xu', 'state': 'Nevada', 'link': 'https://www.bizquest.com/business-broker/sunbelt-business-brokers-of-las-vegas/adam-xu/BW33379/'}, {'company': 'Transworld of So Ut-No Vegas', 'name': 'Judd Whitney', 'state': 'Nevada', 'link': 'https://www.bizquest.com/business-broker/transworld-of-so-ut-no-vegas/judd-whitney/BW40565/'}, {'company': 'Logic Commercial Real Estate', 'name': 'Gino Vincent, CCIM', 'state': 'Las Vegas, Nevada', 'link': 'https://www.bizquest.com/business-broker/logic-commer ...

# %%
import pandas as pd
df = pd.DataFrame(brokers)
df.head()
# Out:
#                                         company             name  \
# 0  Transworld Business Advisors South Las Vegas  Michael Johnson
# 1         Sunbelt Business Brokers of Las Vegas     Alan Horwitz
# 2                  Transworld Business Advisors  Bruce Hooker PC
# 3                                         LVCBS     Jim  Handler
# 4                        BHHS NEVADA PROPERTIES   Elizabeth Hahn
#
#                state                                               link
# 0  Henderson, Nevada  https://www.bizquest.com/business-broker/trans...
# 1  Las Vegas, Nevada  https://www.bizquest.com/business-broker/sunbe...
# 2  Las Vegas, Nevada  https://www.bizquest.com/business-broker/trans...
# 3  Henderson, Nevada  https://www.bizquest.com/business-broker/lvcbs...
# 4             Nevada  https://www.bizquest.com/business-broker/bhhs-...

# %% [markdown]
# # Phone number by accessing all urls

# %%
phones = []

for link in df['link']:
    driver = webdriver.Chrome()
    driver.get(link)
    time.sleep(10)

    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    phone_loc = soup.find('span', {'id': 'phone'})
    
    if phone_loc:
        phone = phone_loc.get_text(strip=True)
        phones.append(phone)
    else:
        phones.append('N/A')

    driver.quit()

print(phones)
# Out:
# ['(702) 216-7031', '(702) 714-0229', '(702) 333-4449', '(702) 353-9882', '(702) 493-3252', '(775) 825-3948', '(702) 546-8844', '(725) 724-5962', '(702) 610-1966', '(775) 828-5400', '(702) 538-0514', '(702) 281-4751', '(702) 991-5360', '(702) 808-9816', '(702) 418-4771', '(702) 475-7542', '(702) 807-8037', '(702) 741-0826', '(702) 672-3971', '(702) 954-4113', '(808) 226-7442', '(775) 200-5799', '(702) 321-5291', '(702) 461-9057', '(702) 533-7143']

# %%
df['phone'] = phones
df.head()
# Out:
#                                         company             name  \
# 0  Transworld Business Advisors South Las Vegas  Michael Johnson
# 1         Sunbelt Business Brokers of Las Vegas     Alan Horwitz
# 2                  Transworld Business Advisors  Bruce Hooker PC
# 3                                         LVCBS     Jim  Handler
# 4                        BHHS NEVADA PROPERTIES   Elizabeth Hahn
#
#                state                                               link  \
# 0  Henderson, Nevada  https://www.bizquest.com/business-broker/trans...
# 1  Las Vegas, Nevada  https://www.bizquest.com/business-broker/sunbe...
# 2  Las Vegas, Nevada  https://www.bizquest.com/business-broker/trans...
# 3  Henderson, Nevada  https://www.bizquest.com/business-broker/lvcbs...
# 4             Nevada  https://www.bizquest.com/business-broker/bhhs-...
#
#             phone
# 0  (702) 216-7031
# 1  (702) 714-0229
# 2  (702) 333-4449
# 3  (702) 353-9882
# 4  (702) 493-3252

# %%
df.tail()
# Out:
#                              company              name              state  \
# 20                Ohana Realty Group      Scott Suzuki             Nevada
# 21             M&A Business Advisors      Rei Robinett       Reno, Nevada
# 22  JW Michaels Realty Services, LLC     Jose Pichardo             Nevada
# 23     First Choice Business Brokers  Kathleen Nichols  Las Vegas, Nevada
# 24               Sin City Realty LLC   Savannah Newman             Nevada
#
#                                                  link           phone
# 20  https://www.bizquest.com/business-broker/ohana...  (808) 226-7442
# 21  https://www.bizquest.com/business-broker/manda...  (775) 200-5799
# 22  https://www.bizquest.com/business-broker/jw-mi...  (702) 321-5291
# 23  https://www.bizquest.com/business-broker/first...  (702) 461-9057
# 24  https://www.bizquest.com/business-broker/sin-c...  (702) 533-7143

# %%
df.to_excel('nevada3.xlsx')
