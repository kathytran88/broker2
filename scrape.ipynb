# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
import time 

driver = webdriver.Chrome()
driver.get('https://www.bizquest.com/arizona-business-brokers/page-6/')
time.sleep(10)

page_source = driver.page_source 
soup = BeautifulSoup(page_source, 'html.parser')

## Dictionary ##
brokers = []

locations = soup.find_all('div', {'class': 'row broker'})

for location in locations:
    broker = {
        'company': 'N/A',
        'name': 'N/A',
        'state': 'N/A',
        'link': 'N/A'
    }

    # Link
    try:
        #link_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
        link_loc2 = location.find('a', {'class': "bnw-result"})
        link = link_loc2['href']
        broker['link'] = link
    except:
         print('No url found')

    # Name 
    try:
         #name_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
         #name_loc2 = name_loc1.find('div', {'class': 'brokerInfo'})
         #name_loc3 = name_loc2.find('a', {'class': 'bnw-result'})
         name_loc4 = location.find('p', {'class': 'brokerName'})
         name = name_loc4.contents[0].strip()
         broker['name'] = name
    except:
         print('No name found')

    # State & Company
    try:
         #state_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCompany'})
         state_loc2 = location.find('p', {'class': 'brokerage'})
         company = state_loc2.contents[0].strip()

         state_loc3 = state_loc2.find('span', {'class': 'brokerLocation'})
         state = state_loc3.get_text(strip=True)

         broker['company'] = company 
         broker['state'] = state
    except:
         print('No state and company found')

    # Add 
    brokers.append(broker)

driver.quit()

# %%
print(brokers)
# Out:
# [{'company': 'Commercial Plus Group', 'name': 'Alexander Pavone', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/commercial-plus-group/alexander-pavone/BW40513/'}, {'company': 'Nystrom Business Sales', 'name': 'Dave & Josh Nystrom', 'state': 'Cave Creek, Arizona', 'link': 'https://www.bizquest.com/business-broker/nystrom-business-sales/dave-and-josh-nystrom/BW1560/'}, {'company': 'HUB Commercial | Sunbelt Business Brokers', 'name': 'Sharon Mortensen', 'state': 'Prescott, Arizona', 'link': 'https://www.bizquest.com/business-broker/hub-commercial-sunbelt-business-brokers/sharon-mortensen/BW41057/'}, {'company': 'West USA Realty, Inc. Business Opportunity', 'name': 'Jason A. Morgan Sr., CM&AA', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/west-usa-realty-inc-business-opportunity/jason-a-morgan-sr-cmandaa/BW28947/'}, {'company': 'Desert Business Brokers', 'name': 'Valori  Mejia', 'state': 'Phoenix, Arizona', 'link': 'https://www.bizquest.com/business-broker/desert-business-brokers/valori-mejia/BW8337/'}, {'company': 'Trust Business Brokers - WEST USA Realty', 'name': 'Kevin McNeill', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/trust-business-brokers-west-usa-realty/kevin-mcneill/BW35616/'}, {'company': 'WCI Business Brokers Northern Arizona', 'name': 'Peggy  Marsh', 'state': 'Arizona', 'link': 'https://www.bizquest.com/business-broker/wci-business-brokers-northern-arizona/peggy-marsh/BW19411/'}, {'company': 'Allen & Young Business Brokerage', 'name': 'Charles Magoffin, CBB', 'state': 'Tucson, Arizona', 'link': 'https://www.bizquest.com/business-broker/allen-and-young-business-brokerage/charles-magoffin-cbb/BW29438/'}, {'company': 'Trust Business Brokers - WEST USA Realty', 'name': 'Ethel Luzario', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/trust-business-brokers-west-usa-realty/ethel-luzario/BW40577/'}, {'company': 'Arizona Business Sales Advisors', 'name': 'David Long', 'state': 'Tempe, Arizona', 'link': 'https://www.bizquest.com/business-broker/arizona-business-sales-advisors/david-long/BW45183/'}, {'company': 'Business Brokers of Arizona', 'name': 'Kyle LeMay', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/business-brokers-of-arizona/kyle-lemay/BW46920/'}, {'company': 'The Paragon Group-West USA Realty', 'name': 'Arnie Lakeyn', 'state': 'Tempe, Arizona', 'link': 'https://www.bizquest.com/business-broker/the-paragon-group-west-usa-realty/arnie-lakeyn/BW18673/'}, {'company': 'Transworld', 'name': 'Arvle Knight', 'state': 'Phoenix, Arizona', 'link': 'https://www.bizquest.com/business-broker/transworld/arvle-knight/BW47125/'}, {'company': 'Transworld Business Advisors', 'name': 'Arvle Knight', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors/arvle-knight/BW46759/'}, {'company': 'Delta Business Advisors', 'name': 'Hanna Hansen', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/delta-business-advisors/hanna-hansen/BW47555/'}, {'company': 'Ray Haiber | Arizona Business Broker', 'name': 'Ray Haiber', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/ray-haiber-arizona-business-broker/ray-haiber/BW17273/'}, {'company': 'Commercial Plus Group', 'name': 'Commercial Plus Group', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/commercial-plus-group/commercial-plus-group/BW6235/'}, {'company': 'Kelly & Call Business Brokerage', 'name': 'Rob Gerlak', 'state': 'Arizona', 'link': 'https://www.bizquest.com/business-broker/kelly-and-call-business-brokerage/rob-gerlak/BW48287/'}, {'company': 'Keyser', 'name': 'Tyler Geopfert', 'state': 'Scottsdale, Arizona', 'link': 'https://www.bizquest.com/business-broker/keyser/tyler-geopfert/BW41039/'}, {'company': 'NAI Horizon', 'name': 'Michael Gaida', 'state': 'Phoeni ...

# %%
import pandas as pd
df = pd.DataFrame(brokers)
df.head()
# Out:
#                                       company                        name  \
# 0                       Commercial Plus Group            Alexander Pavone
# 1                      Nystrom Business Sales         Dave & Josh Nystrom
# 2   HUB Commercial | Sunbelt Business Brokers            Sharon Mortensen
# 3  West USA Realty, Inc. Business Opportunity  Jason A. Morgan Sr., CM&AA
# 4                     Desert Business Brokers               Valori  Mejia
#
#                  state                                               link
# 0  Scottsdale, Arizona  https://www.bizquest.com/business-broker/comme...
# 1  Cave Creek, Arizona  https://www.bizquest.com/business-broker/nystr...
# 2    Prescott, Arizona  https://www.bizquest.com/business-broker/hub-c...
# 3  Scottsdale, Arizona  https://www.bizquest.com/business-broker/west-...
# 4     Phoenix, Arizona  https://www.bizquest.com/business-broker/deser...

# %% [markdown]
# # Phone number by accessing all urls

# %%
phones = []

for link in df['link']:
    driver = webdriver.Chrome()
    driver.get(link)
    time.sleep(10)

    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    phone_loc = soup.find('span', {'id': 'phone'})
    
    if phone_loc:
        phone = phone_loc.get_text(strip=True)
        phones.append(phone)
    else:
        phones.append('N/A')

    driver.quit()

print(phones)
# Out:
# ['(480) 581-1000', '(480) 778-8350', '(928) 642-7984', '(602) 573-3738', '(602) 722-4231', '(602) 397-6000', '(928) 445-1144', '(520) 891-5559', '(602) 549-1011', '(623) 295-9620', '(480) 910-9000', '(480) 776-5831', '(602) 885-8000', '(602) 885-8000', '(480) 359-2099', '(602) 292-0553', '(480) 581-1000', '(928) 440-5450', '(480) 500-5066', '602.920.8940', '(602) 330-6972', '(520) 775-3308', '(480) 477-6305', '(602) 858-0057', '(623) 257-0084']

# %%
df['phone'] = phones
df.head()
# Out:
#                                       company                        name  \
# 0                       Commercial Plus Group            Alexander Pavone
# 1                      Nystrom Business Sales         Dave & Josh Nystrom
# 2   HUB Commercial | Sunbelt Business Brokers            Sharon Mortensen
# 3  West USA Realty, Inc. Business Opportunity  Jason A. Morgan Sr., CM&AA
# 4                     Desert Business Brokers               Valori  Mejia
#
#                  state                                               link  \
# 0  Scottsdale, Arizona  https://www.bizquest.com/business-broker/comme...
# 1  Cave Creek, Arizona  https://www.bizquest.com/business-broker/nystr...
# 2    Prescott, Arizona  https://www.bizquest.com/business-broker/hub-c...
# 3  Scottsdale, Arizona  https://www.bizquest.com/business-broker/west-...
# 4     Phoenix, Arizona  https://www.bizquest.com/business-broker/deser...
#
#             phone
# 0  (480) 581-1000
# 1  (480) 778-8350
# 2  (928) 642-7984
# 3  (602) 573-3738
# 4  (602) 722-4231

# %%
df.tail()
# Out:
#                      company           name                state  \
# 20   American Realty Brokers  Linda Forzani  Scottsdale, Arizona
# 21  Benchmark Business Group   Tom Forsythe              Arizona
# 22        The Wheatley Group  Steve  Ferber  Scottsdale, Arizona
# 23  Century 21 Toma Partners   Stacy Dragos      Peoria, Arizona
# 24        Transworld Phoenix  Darrell Doust              Arizona
#
#                                                  link           phone
# 20  https://www.bizquest.com/business-broker/ameri...  (602) 330-6972
# 21  https://www.bizquest.com/business-broker/bench...  (520) 775-3308
# 22  https://www.bizquest.com/business-broker/the-w...  (480) 477-6305
# 23  https://www.bizquest.com/business-broker/centu...  (602) 858-0057
# 24  https://www.bizquest.com/business-broker/trans...  (623) 257-0084

# %%
df.to_excel('ariozona6.xlsx')
