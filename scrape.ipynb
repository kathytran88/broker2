# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
import time 

driver = webdriver.Chrome()
driver.get('https://www.bizquest.com/arkansas-business-brokers/page-2/')
time.sleep(10)

page_source = driver.page_source 
soup = BeautifulSoup(page_source, 'html.parser')

## Dictionary ##
brokers = []

locations = soup.find_all('div', {'class': 'row broker'})

for location in locations:
    broker = {
        'company': 'N/A',
        'name': 'N/A',
        'state': 'N/A',
        'link': 'N/A'
    }

    # Link
    try:
        #link_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
        link_loc2 = location.find('a', {'class': "bnw-result"})
        link = link_loc2['href']
        broker['link'] = link
    except:
         print('No url found')

    # Name 
    try:
         #name_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
         #name_loc2 = name_loc1.find('div', {'class': 'brokerInfo'})
         #name_loc3 = name_loc2.find('a', {'class': 'bnw-result'})
         name_loc4 = location.find('p', {'class': 'brokerName'})
         name = name_loc4.contents[0].strip()
         broker['name'] = name
    except:
         print('No name found')

    # State & Company
    try:
         #state_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCompany'})
         state_loc2 = location.find('p', {'class': 'brokerage'})
         company = state_loc2.contents[0].strip()

         state_loc3 = state_loc2.find('span', {'class': 'brokerLocation'})
         state = state_loc3.get_text(strip=True)

         broker['company'] = company 
         broker['state'] = state
    except:
         print('No state and company found')

    # Add 
    brokers.append(broker)

driver.quit()

# %%
print(brokers)
# Out:
# [{'company': 'Texas Business for Sale L.L.C.', 'name': 'YVETTE CRINER', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/texas-business-for-sale-l-l-c/yvette-criner/BW47078/'}, {'company': 'Crye-Leike Commercial', 'name': 'Mack Browder', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/crye-leike-commercial/mack-browder/BW27143/'}, {'company': 'Black Diamond Capital Advisory Firm', 'name': 'Christian Baldwin', 'state': 'Fayetteville, Arkansas', 'link': 'https://www.bizquest.com/business-broker/black-diamond-capital-advisory-firm/christian-baldwin/BW20276/'}, {'company': 'United Country Altaterra Realty & Auction, LLC', 'name': 'JW Ross', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/united-country-altaterra-realty-and-auction-llc/jw-ross/BW48014/'}, {'company': 'Acker Robison Realty', 'name': 'Ralph Michael Robison', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/acker-robison-realty/ralph-michael-robison/BW46405/'}, {'company': 'SUNBELT BUSINESS BROKERS OF ARKANSAS', 'name': 'Erik  de Renouard', 'state': 'Little Rock, Arkansas', 'link': 'https://www.bizquest.com/business-broker/sunbelt-business-brokers-of-arkansas/erik-de-renouard/BW11874/'}, {'company': 'M&A Specialists', 'name': 'Ashton Woodward', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/manda-specialists/ashton-woodward/BW45273/'}, {'company': 'M&A Specialists', 'name': 'Jeff Whitham', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/manda-specialists/jeff-whitham/BW45553/'}, {'company': 'Allan Taylor & Co.', 'name': 'Barbara Taylor', 'state': 'Bentonville, Arkansas', 'link': 'https://www.bizquest.com/business-broker/allan-taylor-and-co/barbara-taylor/BW18116/'}, {'company': 'Century 21 Commercial Parker & Scroggins Realty', 'name': 'Eric  Shelnut', 'state': 'Benton, Arkansas', 'link': 'https://www.bizquest.com/business-broker/century-21-commercial-parker-and-scroggins-realty/eric-shelnut/BW28333/'}, {'company': 'AEGIS Business Brokers', 'name': 'Richard Roberts', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/aegis-business-brokers/richard-roberts/BW39288/'}, {'company': 'CBI Team', 'name': 'Charles Rateliff', 'state': 'Springdale, Arkansas', 'link': 'https://www.bizquest.com/business-broker/cbi-team/charles-rateliff/BW40560/'}, {'company': 'CBI Team', 'name': 'James Quick', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/cbi-team/james-quick/BW46784/'}, {'company': 'Transworld Business Advisors of NWA', 'name': "Brian O'Connell", 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors-of-nwa/brian-o-connell/BW46850/'}, {'company': 'CBI Team', 'name': 'Jon Holbert, CBI', 'state': 'Springdale, Arkansas', 'link': 'https://www.bizquest.com/business-broker/cbi-team/jon-holbert-cbi/BW37594/'}, {'company': 'CBI Team', 'name': 'Casey Grimes', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/cbi-team/casey-grimes/BW47740/'}, {'company': 'CBI Team', 'name': 'John Green', 'state': 'Springdale, Arkansas', 'link': 'https://www.bizquest.com/business-broker/cbi-team/john-green/BW40686/'}, {'company': 'Accounting Biz Brokers, LLC.', 'name': 'Kathy Brents', 'state': 'Conway, Arkansas', 'link': 'https://www.bizquest.com/business-broker/accounting-biz-brokers-llc/kathy-brents/BW22154/'}, {'company': 'Black Diamond Capital Advisory Firm', 'name': 'Sahba Talebi', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/black-diamond-capital-advisory-firm/sahba-talebi/BW47017/'}, {'company': 'Black Diamond Capital Advisory Firm', 'name': 'Andy Riethmaier', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/business-broker/black-diamond-capital-advisory-firm/andy-riethmaier/BW46683/'}, {'company': 'Black Diamond Capital Advisory Firm', 'name': 'Chase Piotrowski', 'state': 'Arkansas', 'link': 'https://www.bizquest.com/busin ...

# %%
import pandas as pd
df = pd.DataFrame(brokers)
df.head()
# Out:
#                                           company                   name  \
# 0                  Texas Business for Sale L.L.C.          YVETTE CRINER
# 1                           Crye-Leike Commercial           Mack Browder
# 2             Black Diamond Capital Advisory Firm      Christian Baldwin
# 3  United Country Altaterra Realty & Auction, LLC                JW Ross
# 4                            Acker Robison Realty  Ralph Michael Robison
#
#                     state                                               link
# 0                Arkansas  https://www.bizquest.com/business-broker/texas...
# 1                Arkansas  https://www.bizquest.com/business-broker/crye-...
# 2  Fayetteville, Arkansas  https://www.bizquest.com/business-broker/black...
# 3                Arkansas  https://www.bizquest.com/business-broker/unite...
# 4                Arkansas  https://www.bizquest.com/business-broker/acker...

# %% [markdown]
# # Phone number by accessing all urls

# %%
phones = []

for link in df['link']:
    driver = webdriver.Chrome()
    driver.get(link)
    time.sleep(10)

    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    phone_loc = soup.find('span', {'id': 'phone'})
    
    if phone_loc:
        phone = phone_loc.get_text(strip=True)
        phones.append(phone)
    else:
        phones.append('N/A')

    driver.quit()

print(phones)
# Out:
# ['(346) 370-7980', '(901) 568-4444', '(479) 365-4307', '(903) 438-2585', '(901) 262-1284', '(501) 224-2111', '(501) 240-5059', '(479) 899-5545', '(479) 254-7887', '(501) 317-6653', '(479) 439-8559', '(479) 586-2420', '(501) 773-1239', '(479) 717-4433', '(479) 957-5139', '(479) 770-8989', '(479) 236-9759', '(866) 260-2793', '(479) 619-7444', '(812) 760-6747', '(615) 626-0890', '(479) 806-3707', '(479) 466-5942', '(501) 213-9518']

# %%
df['phone'] = phones
df.head()
# Out:
#                                           company                   name  \
# 0                  Texas Business for Sale L.L.C.          YVETTE CRINER
# 1                           Crye-Leike Commercial           Mack Browder
# 2             Black Diamond Capital Advisory Firm      Christian Baldwin
# 3  United Country Altaterra Realty & Auction, LLC                JW Ross
# 4                            Acker Robison Realty  Ralph Michael Robison
#
#                     state                                               link  \
# 0                Arkansas  https://www.bizquest.com/business-broker/texas...
# 1                Arkansas  https://www.bizquest.com/business-broker/crye-...
# 2  Fayetteville, Arkansas  https://www.bizquest.com/business-broker/black...
# 3                Arkansas  https://www.bizquest.com/business-broker/unite...
# 4                Arkansas  https://www.bizquest.com/business-broker/acker...
#
#             phone
# 0  (346) 370-7980
# 1  (901) 568-4444
# 2  (479) 365-4307
# 3  (903) 438-2585
# 4  (901) 262-1284

# %%
df.tail()
# Out:
#                                 company              name  \
# 19  Black Diamond Capital Advisory Firm   Andy Riethmaier
# 20  Black Diamond Capital Advisory Firm  Chase Piotrowski
# 21                        BMP Solutions         Mike Pate
# 22    Cantrell-Griffin Business Brokers      Barry Graves
# 23  Michele Phillips & Company Realtors        Young Chun
#
#                    state                                               link  \
# 19              Arkansas  https://www.bizquest.com/business-broker/black...
# 20              Arkansas  https://www.bizquest.com/business-broker/black...
# 21  Fort Smith, Arkansas  https://www.bizquest.com/business-broker/bmp-s...
# 22  Springdale, Arkansas  https://www.bizquest.com/business-broker/cantr...
# 23    Sherwood, Arkansas  https://www.bizquest.com/business-broker/miche...
#
#              phone
# 19  (812) 760-6747
# 20  (615) 626-0890
# 21  (479) 806-3707
# 22  (479) 466-5942
# 23  (501) 213-9518

# %%
df.to_excel('arkansas2.xlsx')
