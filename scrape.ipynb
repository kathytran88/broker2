# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
import time 

driver = webdriver.Chrome()
driver.get('https://www.bizquest.com/florida-business-brokers/page-2/')
time.sleep(10)

page_source = driver.page_source 
soup = BeautifulSoup(page_source, 'html.parser')

## Dictionary ##
brokers = []

locations = soup.find_all('div', {'class': 'row broker'})

for location in locations:
    broker = {
        'company': 'N/A',
        'name': 'N/A',
        'state': 'N/A',
        'link': 'N/A'
    }

    # Link
    try:
        #link_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
        link_loc2 = location.find('a', {'class': "bnw-result"})
        link = link_loc2['href']
        broker['link'] = link
    except:
         print('No url found')

    # Name 
    try:
         #name_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
         #name_loc2 = name_loc1.find('div', {'class': 'brokerInfo'})
         #name_loc3 = name_loc2.find('a', {'class': 'bnw-result'})
         name_loc4 = location.find('p', {'class': 'brokerName'})
         name = name_loc4.contents[0].strip()
         broker['name'] = name
    except:
         print('No name found')

    # State & Company
    try:
         #state_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCompany'})
         state_loc2 = location.find('p', {'class': 'brokerage'})
         company = state_loc2.contents[0].strip()

         state_loc3 = state_loc2.find('span', {'class': 'brokerLocation'})
         state = state_loc3.get_text(strip=True)

         broker['company'] = company 
         broker['state'] = state
    except:
         print('No state and company found')

    # Add 
    brokers.append(broker)

driver.quit()

# %%
print(brokers)
# Out:
# [{'company': 'Capital Business Solutions FL Lic', 'name': 'Dale Shepherd', 'state': 'Florida', 'link': 'https://www.bizquest.com/business-broker/capital-business-solutions-fl-lic/dale-shepherd/BW32795/'}, {'company': 'We Sell Construction Businesses', 'name': 'Joseph Shemansky MCBI M&AMI CM&AP', 'state': 'Clermont, Florida', 'link': 'https://www.bizquest.com/business-broker/we-sell-construction-businesses/joseph-shemansky-mcbi-mandami-cmandap/BW27136/'}, {'company': 'AUTHENTIC BUSINESS BROKERS', 'name': 'Elio Serpa', 'state': 'Celebration, Florida', 'link': 'https://www.bizquest.com/business-broker/authentic-business-brokers/elio-serpa/BW29855/'}, {'company': 'Murphy Business Sales', 'name': 'Christopher Sanders', 'state': 'Naples, Florida', 'link': 'https://www.bizquest.com/business-broker/murphy-business-sales/christopher-sanders/BW43743/'}, {'company': 'TEMPUS Business Strategists, LLC', 'name': 'Gil Sanchez', 'state': 'Tampa, Florida', 'link': 'https://www.bizquest.com/business-broker/tempus-business-strategists-llc/gil-sanchez/BW29261/'}, {'company': 'Business Exit Advisors', 'name': 'Joshua D. Sagman', 'state': 'Boca Raton, Florida', 'link': 'https://www.bizquest.com/business-broker/business-exit-advisors/joshua-d-sagman/BW47358/'}, {'company': 'First Choice Business Brokers', 'name': 'Brandy Rumph', 'state': 'Cape Coral, Florida', 'link': 'https://www.bizquest.com/business-broker/first-choice-business-brokers/brandy-rumph/BW43119/'}, {'company': 'The Decain Group', 'name': 'Andy Rumph', 'state': 'Cape Coral, Florida', 'link': 'https://www.bizquest.com/business-broker/the-decain-group/andy-rumph/BW44968/'}, {'company': 'Strategic Medical Brokers LLC', 'name': 'Shaun Rudgear, M&AMI, CBI, CBB', 'state': 'Florida', 'link': 'https://www.bizquest.com/business-broker/strategic-medical-brokers-llc/shaun-rudgear-mandami-cbi-cbb/BW36540/'}, {'company': 'WestVest Associates Inc', 'name': 'Darian Rodriguez', 'state': 'Doral, Florida', 'link': 'https://www.bizquest.com/business-broker/westvest-associates-inc/darian-rodriguez/BW41102/'}, {'company': 'River Brokers', 'name': 'Kavita Purohit', 'state': 'Florida', 'link': 'https://www.bizquest.com/business-broker/river-brokers/kavita-purohit/BW12296/'}, {'company': 'Murphy Business Brokerage in Florida', 'name': 'Michele Pouliot', 'state': 'Freeport, Florida', 'link': 'https://www.bizquest.com/business-broker/murphy-business-brokerage-in-florida/michele-pouliot/BW32738/'}, {'company': 'Brent Arthur Pleeter PLLC', 'name': 'Brent Pleeter', 'state': 'Naples, Florida', 'link': 'https://www.bizquest.com/business-broker/brent-arthur-pleeter-pllc/brent-pleeter/BW45676/'}, {'company': 'Boss Group International, LLC', 'name': 'Jim Parker', 'state': 'Orlando, Florida', 'link': 'https://www.bizquest.com/business-broker/boss-group-international-llc/jim-parker/BW11958/'}, {'company': 'Ocala Business Brokers, Inc.', 'name': 'CONNIE ANN PENDLETON', 'state': 'Ocala, Florida', 'link': 'https://www.bizquest.com/business-broker/ocala-business-brokers-inc/connie-ann-pendleton/BW11673/'}, {'company': 'Global Business Brokers & Valuations Inc', 'name': 'Michael Nunnery', 'state': 'Tampa, Florida', 'link': 'https://www.bizquest.com/business-broker/global-business-brokers-and-valuations-inc/michael-nunnery/BW44220/'}, {'company': 'Infinity Business Brokers', 'name': 'Michael Monnot', 'state': 'Lakewood Ranch, Florida', 'link': 'https://www.bizquest.com/business-broker/infinity-business-brokers/michael-monnot/BW21789/'}, {'company': 'Transworld Business Brokers, LLC.', 'name': 'Thomas R. Milana P.A.', 'state': 'Fort Lauderdale, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-brokers-llc/thomas-r-milana-p-a/BW32290/'}, {'company': 'Pointe Automotive Advisors', 'name': 'David Melton', 'state': 'Florida', 'link': 'https://www.bizquest.com/business-broker/pointe-automotive-advisors/david-melton/BW46193/'}, {'company': 'Transworld Business Brokers', 'name': 'Fernando Mello, MBA, CBI', ...

# %%
import pandas as pd
df = pd.DataFrame(brokers)
df.head()
# Out:
#                              company                               name  \
# 0  Capital Business Solutions FL Lic                      Dale Shepherd
# 1    We Sell Construction Businesses  Joseph Shemansky MCBI M&AMI CM&AP
# 2         AUTHENTIC BUSINESS BROKERS                         Elio Serpa
# 3              Murphy Business Sales                Christopher Sanders
# 4   TEMPUS Business Strategists, LLC                        Gil Sanchez
#
#                   state                                               link
# 0               Florida  https://www.bizquest.com/business-broker/capit...
# 1     Clermont, Florida  https://www.bizquest.com/business-broker/we-se...
# 2  Celebration, Florida  https://www.bizquest.com/business-broker/authe...
# 3       Naples, Florida  https://www.bizquest.com/business-broker/murph...
# 4        Tampa, Florida  https://www.bizquest.com/business-broker/tempu...

# %% [markdown]
# # Phone number by accessing all urls

# %%
phones = []

for link in df['link']:
    driver = webdriver.Chrome()
    driver.get(link)
    time.sleep(10)

    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    phone_loc = soup.find('span', {'id': 'phone'})
    
    if phone_loc:
        phone = phone_loc.get_text(strip=True)
        phones.append(phone)
    else:
        phones.append('N/A')

    driver.quit()

print(phones)
# Out:
# ['(954) 789-4441', '(352) 404-9191', '(407) 558-8640', '(239) 799-0017', '813.210.9135', '(561) 388-8888', '(239) 790-1277', '(239) 292-5350', '(888) 970-1210', '(786) 307-5545', '(770) 415-9940', '(410) 961-0761', '(239) 744-6893', '(407) 329-3273', '(352) 502-3811', '(305) 439-1585', '(941) 518-7138', '1.561.702.6867', '(423) 713-7019', '(561) 609-7371', '(407) 388-8268', '(954) 775-2554', '(847) 701-2767', '(727) 822-8833', '(239) 205-4770']

# %%
df['phone'] = phones
df.head()
# Out:
#                              company                               name  \
# 0  Capital Business Solutions FL Lic                      Dale Shepherd
# 1    We Sell Construction Businesses  Joseph Shemansky MCBI M&AMI CM&AP
# 2         AUTHENTIC BUSINESS BROKERS                         Elio Serpa
# 3              Murphy Business Sales                Christopher Sanders
# 4   TEMPUS Business Strategists, LLC                        Gil Sanchez
#
#                   state                                               link  \
# 0               Florida  https://www.bizquest.com/business-broker/capit...
# 1     Clermont, Florida  https://www.bizquest.com/business-broker/we-se...
# 2  Celebration, Florida  https://www.bizquest.com/business-broker/authe...
# 3       Naples, Florida  https://www.bizquest.com/business-broker/murph...
# 4        Tampa, Florida  https://www.bizquest.com/business-broker/tempu...
#
#             phone
# 0  (954) 789-4441
# 1  (352) 404-9191
# 2  (407) 558-8640
# 3  (239) 799-0017
# 4    813.210.9135

# %%
df.tail()
# Out:
#                        company                name                     state  \
# 20  Meier Business Brokers LLC         David Meier      Winter Park, Florida
# 21         United Realty Group         Alan Mehrez  Fort Lauderdale, Florida
# 22             SourceWorks Inc       James McNeela                   Florida
# 23          Main Street & Main  Main Street & Main   St. Petersburg, Florida
# 24           Liquor License FL          Jason Long       Fort Myers, Florida
#
#                                                  link           phone
# 20  https://www.bizquest.com/business-broker/meier...  (407) 388-8268
# 21  https://www.bizquest.com/business-broker/unite...  (954) 775-2554
# 22  https://www.bizquest.com/business-broker/sourc...  (847) 701-2767
# 23  https://www.bizquest.com/business-broker/main-...  (727) 822-8833
# 24  https://www.bizquest.com/business-broker/liquo...  (239) 205-4770

# %%
df.to_excel('florida2.xlsx')
