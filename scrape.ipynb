# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
import time 

driver = webdriver.Chrome()
driver.get('https://www.bizquest.com/wyoming-business-brokers/')
time.sleep(10)

page_source = driver.page_source 
soup = BeautifulSoup(page_source, 'html.parser')

## Dictionary ##
brokers = []

locations = soup.find_all('div', {'class': 'row broker'})

for location in locations:
    broker = {
        'company': 'N/A',
        'name': 'N/A',
        'state': 'N/A',
        'link': 'N/A'
    }

    # Link
    try:
        #link_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
        link_loc2 = location.find('a', {'class': "bnw-result"})
        link = link_loc2['href']
        broker['link'] = link
    except:
         print('No url found')

    # Name 
    try:
         #name_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
         #name_loc2 = name_loc1.find('div', {'class': 'brokerInfo'})
         #name_loc3 = name_loc2.find('a', {'class': 'bnw-result'})
         name_loc4 = location.find('p', {'class': 'brokerName'})
         name = name_loc4.contents[0].strip()
         broker['name'] = name
    except:
         print('No name found')

    # State & Company
    try:
         #state_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCompany'})
         state_loc2 = location.find('p', {'class': 'brokerage'})
         company = state_loc2.contents[0].strip()

         state_loc3 = state_loc2.find('span', {'class': 'brokerLocation'})
         state = state_loc3.get_text(strip=True)

         broker['company'] = company 
         broker['state'] = state
    except:
         print('No state and company found')

    # Add 
    brokers.append(broker)

driver.quit()

# %%
print(brokers)
# Out:
# [{'company': 'Rocky Mountian Business Advisors', 'name': 'Gregg Kunz, CBI, M&AMI', 'state': 'Wyoming', 'link': 'https://www.bizquest.com/business-broker/rocky-mountian-business-advisors/gregg-kunz-cbi-mandami/BW36380/'}, {'company': 'RE/MAX Elevation', 'name': 'Brenton Hayden', 'state': 'Cody, Wyoming', 'link': 'https://www.bizquest.com/business-broker/re-max-elevation/brenton-hayden/BW48412/'}, {'company': 'The Raivax Group, Inc.', 'name': 'Raaz Ali, MBA, CBI, M&AMI, CM&AA', 'state': 'Wyoming', 'link': 'https://www.bizquest.com/business-broker/the-raivax-group-inc/raaz-ali-mba-cbi-mandami-cmandaa/BW17660/'}, {'company': 'ProformaPartners, LLC', 'name': 'Randy Bernard', 'state': 'Wyoming', 'link': 'https://www.bizquest.com/business-broker/proformapartners-llc/randy-bernard/BW28003/'}, {'company': 'Powers Land Brokerage', 'name': 'Charlie Powers', 'state': 'Sheridan, Wyoming', 'link': 'https://www.bizquest.com/business-broker/powers-land-brokerage/charlie-powers/BW47949/'}, {'company': 'Murphy Business & Financial Corporation', 'name': 'Thomas  Nelson', 'state': 'Wyoming', 'link': 'https://www.bizquest.com/business-broker/murphy-business-and-financial-corporation/thomas-nelson/BW18381/'}, {'company': 'Murphy Business and Financial Corporation', 'name': 'Joe MacGuire', 'state': 'Casper, Wyoming', 'link': 'https://www.bizquest.com/business-broker/murphy-business-and-financial-corporation/joe-macguire/BW30624/'}, {'company': 'Sunbelt Business Brokers of Idaho', 'name': 'Matt Eells', 'state': 'Wyoming', 'link': 'https://www.bizquest.com/business-broker/sunbelt-business-brokers-of-idaho/matt-eells/BW36454/'}, {'company': 'Transworld Business Advisors of Colorado', 'name': 'Jim DeShayes', 'state': 'Wyoming', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors-of-colorado/jim-deshayes/BW47044/'}, {'company': 'Transworld', 'name': 'Gerald Brisson', 'state': 'Cheyenne, Wyoming', 'link': 'https://www.bizquest.com/business-broker/transworld/gerald-brisson/BW47422/'}, {'company': 'Impact Properties LLC', 'name': 'Nic Bateson', 'state': 'Sheriden, Wyoming', 'link': 'https://www.bizquest.com/business-broker/impact-properties-llc/nic-bateson/BW42640/'}, {'company': 'Green Pine Partners, Inc.', 'name': 'Daren Ross', 'state': 'Cheyenne, Wyoming', 'link': 'https://www.bizquest.com/business-broker/green-pine-partners-inc/daren-ross/BW38377/'}, {'company': 'Richard Realty', 'name': 'Scott Richard', 'state': 'Cody, Wyoming', 'link': 'https://www.bizquest.com/business-broker/richard-realty/scott-richard/BW36128/'}, {'company': 'We Sell Restaurants', 'name': 'Jeff Marcus', 'state': 'Wyoming', 'link': 'https://www.bizquest.com/business-broker/we-sell-restaurants/jeff-marcus/BW36125/'}, {'company': 'Pioneer Realty Group LLP', 'name': 'Jason Lonabaugh', 'state': 'Sheridan, Wyoming', 'link': 'https://www.bizquest.com/business-broker/pioneer-realty-group-llp/jason-lonabaugh/BW41582/'}, {'company': 'Cody Country Real Estate', 'name': 'Johnny Hanna', 'state': 'Cody, Wyoming', 'link': 'https://www.bizquest.com/business-broker/cody-country-real-estate/johnny-hanna/BW46387/'}, {'company': 'BrokerOne Real Estate', 'name': 'Randall Hall', 'state': 'Casper, Wyoming', 'link': 'https://www.bizquest.com/business-broker/brokerone-real-estate/randall-hall/BW42655/'}, {'company': 'Transworld', 'name': 'Lamont Muchmore', 'state': 'Cheyenne, Wyoming', 'link': 'https://www.bizquest.com/business-broker/transworld/lamont-muchmore/BW47821/'}, {'company': 'Transworld Business Advisors', 'name': 'Tony Keane', 'state': 'Cheyenne, Wyoming', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors/tony-keane/BW40732/'}, {'company': '#1 Properties', 'name': 'Larry Sutherland', 'state': 'Cheyenne, Wyoming', 'link': 'https://www.bizquest.com/business-broker/1-properties/larry-sutherland/BW39361/'}]

# %%
import pandas as pd
df = pd.DataFrame(brokers)
df.head()
# Out:
#                             company                              name  \
# 0  Rocky Mountian Business Advisors            Gregg Kunz, CBI, M&AMI
# 1                  RE/MAX Elevation                    Brenton Hayden
# 2            The Raivax Group, Inc.  Raaz Ali, MBA, CBI, M&AMI, CM&AA
# 3             ProformaPartners, LLC                     Randy Bernard
# 4             Powers Land Brokerage                    Charlie Powers
#
#                state                                               link
# 0            Wyoming  https://www.bizquest.com/business-broker/rocky...
# 1      Cody, Wyoming  https://www.bizquest.com/business-broker/re-ma...
# 2            Wyoming  https://www.bizquest.com/business-broker/the-r...
# 3            Wyoming  https://www.bizquest.com/business-broker/profo...
# 4  Sheridan, Wyoming  https://www.bizquest.com/business-broker/power...

# %% [markdown]
# # Phone number by accessing all urls

# %%
phones = []

for link in df['link']:
    driver = webdriver.Chrome()
    driver.get(link)
    time.sleep(10)

    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    phone_loc = soup.find('span', {'id': 'phone'})
    
    if phone_loc:
        phone = phone_loc.get_text(strip=True)
        phones.append(phone)
    else:
        phones.append('N/A')

    driver.quit()

print(phones)
# Out:
# ['(303) 474-5582', '(307) 363-0033', '(703) 752-6178', '(303) 427-0800', '(307) 217-2777', '(406) 256-7470', '(307) 333-3653', '(208) 631-5428', '(970) 224-3339', '(281) 769-4277', '(307) 763-7088', '(307) 256-9938', '(307) 586-5440', '(970) 373-8205', '(307) 751-2919', '(307) 587-2803', '(307) 259-4785', '(307) 421-1195', '(307) 690-1868', '(307) 634-2222']

# %%
df['phone'] = phones
df.head()
# Out:
#                             company                              name  \
# 0  Rocky Mountian Business Advisors            Gregg Kunz, CBI, M&AMI
# 1                  RE/MAX Elevation                    Brenton Hayden
# 2            The Raivax Group, Inc.  Raaz Ali, MBA, CBI, M&AMI, CM&AA
# 3             ProformaPartners, LLC                     Randy Bernard
# 4             Powers Land Brokerage                    Charlie Powers
#
#                state                                               link  \
# 0            Wyoming  https://www.bizquest.com/business-broker/rocky...
# 1      Cody, Wyoming  https://www.bizquest.com/business-broker/re-ma...
# 2            Wyoming  https://www.bizquest.com/business-broker/the-r...
# 3            Wyoming  https://www.bizquest.com/business-broker/profo...
# 4  Sheridan, Wyoming  https://www.bizquest.com/business-broker/power...
#
#             phone
# 0  (303) 474-5582
# 1  (307) 363-0033
# 2  (703) 752-6178
# 3  (303) 427-0800
# 4  (307) 217-2777

# %%
df.tail()
# Out:
#                          company              name              state  \
# 15      Cody Country Real Estate      Johnny Hanna      Cody, Wyoming
# 16         BrokerOne Real Estate      Randall Hall    Casper, Wyoming
# 17                    Transworld   Lamont Muchmore  Cheyenne, Wyoming
# 18  Transworld Business Advisors        Tony Keane  Cheyenne, Wyoming
# 19                 #1 Properties  Larry Sutherland  Cheyenne, Wyoming
#
#                                                  link           phone
# 15  https://www.bizquest.com/business-broker/cody-...  (307) 587-2803
# 16  https://www.bizquest.com/business-broker/broke...  (307) 259-4785
# 17  https://www.bizquest.com/business-broker/trans...  (307) 421-1195
# 18  https://www.bizquest.com/business-broker/trans...  (307) 690-1868
# 19  https://www.bizquest.com/business-broker/1-pro...  (307) 634-2222

# %%
df.to_excel('wyoming1.xlsx')
