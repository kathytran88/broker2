# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
import time 

driver = webdriver.Chrome()
driver.get('https://www.bizquest.com/alaska-business-brokers/')
time.sleep(10)

page_source = driver.page_source 
soup = BeautifulSoup(page_source, 'html.parser')

## Dictionary ##
brokers = []

locations = soup.find_all('div', {'class': 'row broker'})

for location in locations:
    broker = {
        'company': 'N/A',
        'name': 'N/A',
        'state': 'N/A',
        'link': 'N/A'
    }

    # Link
    try:
        #link_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
        link_loc2 = location.find('a', {'class': "bnw-result"})
        link = link_loc2['href']
        broker['link'] = link
    except:
         print('No url found')

    # Name 
    try:
         #name_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
         #name_loc2 = name_loc1.find('div', {'class': 'brokerInfo'})
         #name_loc3 = name_loc2.find('a', {'class': 'bnw-result'})
         name_loc4 = location.find('p', {'class': 'brokerName'})
         name = name_loc4.contents[0].strip()
         broker['name'] = name
    except:
         print('No name found')

    # State & Company
    try:
         #state_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCompany'})
         state_loc2 = location.find('p', {'class': 'brokerage'})
         company = state_loc2.contents[0].strip()

         state_loc3 = state_loc2.find('span', {'class': 'brokerLocation'})
         state = state_loc3.get_text(strip=True)

         broker['company'] = company 
         broker['state'] = state
    except:
         print('No state and company found')

    # Add 
    brokers.append(broker)

driver.quit()

# %%
print(brokers)
# Out:
# [{'company': 'Canterbury Realty Group', 'name': 'Kenny Sayyed', 'state': 'Birmingham, Alabama', 'link': 'https://www.bizquest.com/business-broker/canterbury-realty-group/kenny-sayyed/BW38170/'}, {'company': 'Quinn RE Sales', 'name': 'Mandy Quinn', 'state': 'Birmingham, Alabama', 'link': 'https://www.bizquest.com/business-broker/quinn-re-sales/mandy-quinn/BW46015/'}, {'company': 'Transworld Business Advisors of the Gulf Coast', 'name': 'Amanda Morel', 'state': 'Alabama', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors-of-the-gulf-coast/amanda-morel/BW45971/'}, {'company': 'Transworld Business Advisors of the Gulf Coast', 'name': 'Leslie McCleskey', 'state': 'Alabama', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors-of-the-gulf-coast/leslie-mccleskey/BW47564/'}, {'company': 'OLD Inc Business Brokers', 'name': 'Bret Hudson', 'state': 'Alabama', 'link': 'https://www.bizquest.com/business-broker/old-inc-business-brokers/bret-hudson/BW48695/'}, {'company': 'Sunbelt Business Brokers and Business Brokers South', 'name': 'Richard Corrigan', 'state': 'Alabama', 'link': 'https://www.bizquest.com/business-broker/sunbelt-business-brokers-and-business-brokers-south/richard-corrigan/BW43663/'}]

# %%
import pandas as pd
df = pd.DataFrame(brokers)
df.head()
# Out:
#                                           company              name  \
# 0                         Canterbury Realty Group      Kenny Sayyed
# 1                                  Quinn RE Sales       Mandy Quinn
# 2  Transworld Business Advisors of the Gulf Coast      Amanda Morel
# 3  Transworld Business Advisors of the Gulf Coast  Leslie McCleskey
# 4                        OLD Inc Business Brokers       Bret Hudson
#
#                  state                                               link
# 0  Birmingham, Alabama  https://www.bizquest.com/business-broker/cante...
# 1  Birmingham, Alabama  https://www.bizquest.com/business-broker/quinn...
# 2              Alabama  https://www.bizquest.com/business-broker/trans...
# 3              Alabama  https://www.bizquest.com/business-broker/trans...
# 4              Alabama  https://www.bizquest.com/business-broker/old-i...

# %% [markdown]
# # Phone number by accessing all urls

# %%
phones = []

for link in df['link']:
    driver = webdriver.Chrome()
    driver.get(link)
    time.sleep(10)

    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    phone_loc = soup.find('span', {'id': 'phone'})
    
    if phone_loc:
        phone = phone_loc.get_text(strip=True)
        phones.append(phone)
    else:
        phones.append('N/A')

    driver.quit()

print(phones)
# Out:
# ['(205) 266-2757', '(205) 882-3148', '(251) 237-1030', '(251) 237-1030', '(256) 347-9970', '(251) 604-8220']

# %%
df['phone'] = phones
df.head()
# Out:
#                                           company              name  \
# 0                         Canterbury Realty Group      Kenny Sayyed
# 1                                  Quinn RE Sales       Mandy Quinn
# 2  Transworld Business Advisors of the Gulf Coast      Amanda Morel
# 3  Transworld Business Advisors of the Gulf Coast  Leslie McCleskey
# 4                        OLD Inc Business Brokers       Bret Hudson
#
#                  state                                               link  \
# 0  Birmingham, Alabama  https://www.bizquest.com/business-broker/cante...
# 1  Birmingham, Alabama  https://www.bizquest.com/business-broker/quinn...
# 2              Alabama  https://www.bizquest.com/business-broker/trans...
# 3              Alabama  https://www.bizquest.com/business-broker/trans...
# 4              Alabama  https://www.bizquest.com/business-broker/old-i...
#
#             phone
# 0  (205) 266-2757
# 1  (205) 882-3148
# 2  (251) 237-1030
# 3  (251) 237-1030
# 4  (256) 347-9970

# %%
df.tail()
# Out:
#                                              company              name  \
# 1                                     Quinn RE Sales       Mandy Quinn
# 2     Transworld Business Advisors of the Gulf Coast      Amanda Morel
# 3     Transworld Business Advisors of the Gulf Coast  Leslie McCleskey
# 4                           OLD Inc Business Brokers       Bret Hudson
# 5  Sunbelt Business Brokers and Business Brokers ...  Richard Corrigan
#
#                  state                                               link  \
# 1  Birmingham, Alabama  https://www.bizquest.com/business-broker/quinn...
# 2              Alabama  https://www.bizquest.com/business-broker/trans...
# 3              Alabama  https://www.bizquest.com/business-broker/trans...
# 4              Alabama  https://www.bizquest.com/business-broker/old-i...
# 5              Alabama  https://www.bizquest.com/business-broker/sunbe...
#
#             phone
# 1  (205) 882-3148
# 2  (251) 237-1030
# 3  (251) 237-1030
# 4  (256) 347-9970
# 5  (251) 604-8220

# %%
df.to_excel('alaska.xlsx')
