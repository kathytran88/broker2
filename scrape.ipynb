# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
import time 

driver = webdriver.Chrome()
driver.get('https://www.bizquest.com/florida-business-brokers/page-5/')
time.sleep(10)

page_source = driver.page_source 
soup = BeautifulSoup(page_source, 'html.parser')

## Dictionary ##
brokers = []

locations = soup.find_all('div', {'class': 'row broker'})

for location in locations:
    broker = {
        'company': 'N/A',
        'name': 'N/A',
        'state': 'N/A',
        'link': 'N/A'
    }

    # Link
    try:
        #link_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
        link_loc2 = location.find('a', {'class': "bnw-result"})
        link = link_loc2['href']
        broker['link'] = link
    except:
         print('No url found')

    # Name 
    try:
         #name_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCard'})
         #name_loc2 = name_loc1.find('div', {'class': 'brokerInfo'})
         #name_loc3 = name_loc2.find('a', {'class': 'bnw-result'})
         name_loc4 = location.find('p', {'class': 'brokerName'})
         name = name_loc4.contents[0].strip()
         broker['name'] = name
    except:
         print('No name found')

    # State & Company
    try:
         #state_loc1 = location.find('div', {'class': 'col-xs-12 col-sm-6 brokerCompany'})
         state_loc2 = location.find('p', {'class': 'brokerage'})
         company = state_loc2.contents[0].strip()

         state_loc3 = state_loc2.find('span', {'class': 'brokerLocation'})
         state = state_loc3.get_text(strip=True)

         broker['company'] = company 
         broker['state'] = state
    except:
         print('No state and company found')

    # Add 
    brokers.append(broker)

driver.quit()

# %%
print(brokers)
# Out:
# [{'company': 'Sunbelt Business Brokers and Business Brokers South', 'name': 'David Chew, CBI', 'state': 'Florida', 'link': 'https://www.bizquest.com/business-broker/sunbelt-business-brokers-and-business-brokers-south/david-chew-cbi/BW922/'}, {'company': 'Sunbelt Business Brokers of South Florida', 'name': 'Ryan  Cave', 'state': 'North Palm Beach, Florida', 'link': 'https://www.bizquest.com/business-broker/sunbelt-business-brokers-of-south-florida/ryan-cave/BW417/'}, {'company': 'Liquor License Professionals, LLC', 'name': 'Robert B Casey', 'state': 'Maitland, Florida', 'link': 'https://www.bizquest.com/business-broker/liquor-license-professionals-llc/robert-b-casey/BW31963/'}, {'company': 'Sunbelt Business Brokers of South Florida', 'name': 'David Carson', 'state': 'North Palm Beach, Florida', 'link': 'https://www.bizquest.com/business-broker/sunbelt-business-brokers-of-south-florida/david-carson/BW41642/'}, {'company': 'TCG Business Brokers', 'name': 'Carlos Cardenas', 'state': 'Pembroke  Pines, Florida', 'link': 'https://www.bizquest.com/business-broker/tcg-business-brokers/carlos-cardenas/BW42675/'}, {'company': 'CAPITAL BUSINESS SOLUTIONS', 'name': 'Roberta  Caputo', 'state': 'Deerfield Beach, Florida', 'link': 'https://www.bizquest.com/business-broker/capital-business-solutions/roberta-caputo/BW1185/'}, {'company': 'Transworld M&A Advisors', 'name': 'Andy Cagnetta', 'state': 'St. Petersburg, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-manda-advisors/andy-cagnetta/BW36338/'}, {'company': 'Transworld Business Brokers of Central Florida', 'name': 'Andrew  Cagnetta', 'state': 'Ocala, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-brokers-of-central-florida/andrew-cagnetta/BW15264/'}, {'company': 'Transworld Business Brokers', 'name': 'Andrew  Cagnetta', 'state': 'Jacksonville, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-brokers/andrew-cagnetta/BW5620/'}, {'company': 'Transworld Business Brokers', 'name': 'Andrew  Cagnetta', 'state': 'Miami, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-brokers/andrew-cagnetta/BW15261/'}, {'company': 'Transworld Business Brokers, LLC', 'name': 'Andrew  Cagnetta', 'state': 'Port Saint Lucie, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-brokers-llc/andrew-cagnetta/BW15263/'}, {'company': 'Transworld Business Brokers of Central F', 'name': 'Andrew  Cagnetta', 'state': 'Orlando, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-brokers-of-central-f/andrew-cagnetta/BW3027/'}, {'company': 'Transworld Business Brokers', 'name': 'Andrew  Cagnetta', 'state': 'West Palm Beach, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-brokers/andrew-cagnetta/BW15262/'}, {'company': 'Transworld Business Brokers, LLC.', 'name': 'Andrew  Cagnetta', 'state': 'Fort Lauderdale, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-brokers-llc/andrew-cagnetta/BW870/'}, {'company': 'Transworld Business Advisors of Central Florida', 'name': 'Andrew Cagnetta', 'state': 'Melbourne, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors-of-central-florida/andrew-cagnetta/BW15017/'}, {'company': 'Transworld Business Advisors of Tampa', 'name': 'Andrew Cagnetta', 'state': 'St. Petersburg, Florida', 'link': 'https://www.bizquest.com/business-broker/transworld-business-advisors-of-tampa/andrew-cagnetta/BW32603/'}, {'company': 'Truforte Business Group', 'name': 'Truforte  Business Group', 'state': 'Fort Myers, Florida', 'link': 'https://www.bizquest.com/business-broker/truforte-business-group/truforte-business-group/BW14277/'}, {'company': 'Corporate Investment Business Brokers', 'name': 'CIBB, Corporate Investment Business Brokers', 'state': 'Fort Myers, Florida', 'link': 'https://www.bizquest.com/business-broker/corporate-investment-business-broke ...

# %%
import pandas as pd
df = pd.DataFrame(brokers)
df.head()
# Out:
#                                              company             name  \
# 0  Sunbelt Business Brokers and Business Brokers ...  David Chew, CBI
# 1          Sunbelt Business Brokers of South Florida       Ryan  Cave
# 2                  Liquor License Professionals, LLC   Robert B Casey
# 3          Sunbelt Business Brokers of South Florida     David Carson
# 4                               TCG Business Brokers  Carlos Cardenas
#
#                        state  \
# 0                    Florida
# 1  North Palm Beach, Florida
# 2          Maitland, Florida
# 3  North Palm Beach, Florida
# 4   Pembroke  Pines, Florida
#
#                                                 link
# 0  https://www.bizquest.com/business-broker/sunbe...
# 1  https://www.bizquest.com/business-broker/sunbe...
# 2  https://www.bizquest.com/business-broker/liquo...
# 3  https://www.bizquest.com/business-broker/sunbe...
# 4  https://www.bizquest.com/business-broker/tcg-b...

# %% [markdown]
# # Phone number by accessing all urls

# %%
phones = []

for link in df['link']:
    driver = webdriver.Chrome()
    driver.get(link)
    time.sleep(10)

    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    phone_loc = soup.find('span', {'id': 'phone'})
    
    if phone_loc:
        phone = phone_loc.get_text(strip=True)
        phones.append(phone)
    else:
        phones.append('N/A')

    driver.quit()

print(phones)
# Out:
# ['(251) 626-4949', '(561) 832-9222', '(321) 274-7104', '(949) 339-1500', '(305) 525-8749', '(954) 596-8060', '(888) 864-6610', '(352) 351-3322', '(904) 992-2223', '(305) 949-1199', '(772) 380-0073', '(407) 226-7171', '(561) 627-8887', '(954) 772-1122', '(321) 255-6022', '(813) 579-4920', '(239) 284-1317', '(239) 936-1718', '(727) 725-7090', '(954) 913-5464', '(941) 224-3893', '(352) 726-6668', '(813) 493-2913', '(239) 357-7073', '(814) 280-7832']

# %%
df['phone'] = phones
df.head()
# Out:
#                                              company             name  \
# 0  Sunbelt Business Brokers and Business Brokers ...  David Chew, CBI
# 1          Sunbelt Business Brokers of South Florida       Ryan  Cave
# 2                  Liquor License Professionals, LLC   Robert B Casey
# 3          Sunbelt Business Brokers of South Florida     David Carson
# 4                               TCG Business Brokers  Carlos Cardenas
#
#                        state  \
# 0                    Florida
# 1  North Palm Beach, Florida
# 2          Maitland, Florida
# 3  North Palm Beach, Florida
# 4   Pembroke  Pines, Florida
#
#                                                 link           phone
# 0  https://www.bizquest.com/business-broker/sunbe...  (251) 626-4949
# 1  https://www.bizquest.com/business-broker/sunbe...  (561) 832-9222
# 2  https://www.bizquest.com/business-broker/liquo...  (321) 274-7104
# 3  https://www.bizquest.com/business-broker/sunbe...  (949) 339-1500
# 4  https://www.bizquest.com/business-broker/tcg-b...  (305) 525-8749

# %%
df.tail()
# Out:
#                                               company  \
# 20                              Business Broker World
# 21                 Century 21 J.W. Morton Real Estate
# 22                     Tam-Bay Mergers & Acquisitions
# 23  Sunbelt Business Brokers of Naples, Sarasota a...
# 24                      Happy Valley Business Brokers
#
#                        name               state  \
# 20  Dr.Denis Burke, DBA MBA  Bradenton, Florida
# 21             Wayne Buhler  Inverness, Florida
# 22             Tom Brubaker      Tampa, Florida
# 23             Jason Brooks     Naples, Florida
# 24           Terri Breindel             Florida
#
#                                                  link           phone
# 20  https://www.bizquest.com/business-broker/busin...  (941) 224-3893
# 21  https://www.bizquest.com/business-broker/centu...  (352) 726-6668
# 22  https://www.bizquest.com/business-broker/tam-b...  (813) 493-2913
# 23  https://www.bizquest.com/business-broker/sunbe...  (239) 357-7073
# 24  https://www.bizquest.com/business-broker/happy...  (814) 280-7832

# %%
df.to_excel('florida5.xlsx')
